# %% [markdown]
# $$
# u = x^2 + y + 5 \\
# f_1 = -\frac{\partial}{\partial x}(2 * 2x) = -4 \\
# f_2 = -\frac{\partial}{\partial x}(3 * 2x) = -6 \\
# \theta = -\lambda\frac{\partial u}{\partial x} = -2 * 2x = -4x
# $$

# %%
import pyvista as pv

# %%
reader = pv.CGNSReader('out/temp.cgns')
msh = reader.read()
plotter = pv.Plotter()

print(msh)

plotter.add_mesh(msh, show_edges=True, scalars='Temperature')
plotter.camera_position = 'xy'
plotter.show_axes()
plotter.show(jupyter_backend='static')
# Out:
# 2026-03-09 11:42:03.200 (25995.006s) [    7F86375A3740] vtkEGLRenderWindow.cxx:391   WARN| vtkEGLRenderWindow (0x55b5dfddc7e0): Setting an EGL display to device index: -1 require EGL_EXT_device_base EGL_EXT_platform_device EGL_EXT_platform_base extensions
# 2026-03-09 11:42:03.200 (25995.006s) [    7F86375A3740] vtkEGLRenderWindow.cxx:396   WARN| vtkEGLRenderWindow (0x55b5dfddc7e0): Attempting to use EGL_DEFAULT_DISPLAY...
# 2026-03-09 11:42:03.200 (25995.006s) [    7F86375A3740] vtkEGLRenderWindow.cxx:401   WARN| vtkEGLRenderWindow (0x55b5dfddc7e0): Could not initialize a device. Exiting...
# 2026-03-09 11:42:03.201 (25995.007s) [    7F86375A3740]vtkOpenGLRenderWindow.c:920   WARN| vtkEGLRenderWindow (0x55b5dfddc7e0): Failed to initialize OpenGL functions!
# ...
